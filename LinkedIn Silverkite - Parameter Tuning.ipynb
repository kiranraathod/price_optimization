# %% [markdown]
# #Libraries and data

# %%
#libraries
import numpy as np
import pandas as pd
from greykite.framework.templates.autogen.forecast_config import *
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.common.features.timeseries_features import *
from greykite.common.evaluation import EvaluationMetricEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from plotly.offline import iplot

# %%
df = pd.read_csv('./files/furniture_decor_data.csv')
df
# Out:
#      Unnamed: 0                 date  price  freight_value  quantity_sold  \
# 0             0  2017-07-25 10:50:22   75.0          13.08              1
# 1             1  2017-07-28 14:20:19   75.0          20.02              1
# 2             2  2017-07-28 15:56:14   75.0          20.02              1
# 3             3  2017-07-29 13:22:44   75.0          13.08              2
# 4             4  2017-08-01 13:11:47   75.0          13.08              3
# ..          ...                  ...    ...            ...            ...
# 420         420  2018-07-11 18:26:53   89.9          32.65              1
# 421         421  2018-07-22 13:09:08   89.9          26.93              1
# 422         422  2018-08-06 15:21:10   89.9          17.76              1
# 423         423  2018-08-09 11:07:40  109.9          22.07              1
# 424         424  2018-08-18 16:37:58  109.9          27.07              1
#
#      cci_value  unemr_value  inflation_value
# 0     99.34319         12.8         2.711626
# 1     99.34319         12.8         2.711626
# 2     99.34319         12.8         2.711626
# 3     99.34319         12.8         2.711626
# 4     99.37289         12.6         2.455909
# ..         ...          ...              ...
# 420   99.66840         12.3         4.484844
# 421   99.66840         12.3         4.484844
# 422   99.62103         12.1         4.193016
# 423   99.62103         12.1         4.193016
# 424   99.62103         12.1         4.193016
#
# [425 rows x 8 columns]

# %%
# Drop the 'Unnamed: 0' column
df = df.drop(columns=['Unnamed: 0'])

# Extract the date portion from the 'date' column
df['date'] = pd.to_datetime(df['date']).dt.date

# Convert the 'date' column to 'dd/mm/yyyy' format
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d').dt.strftime('%d/%m/%Y')

df.head()
# Out:
#          date  price  freight_value  quantity_sold  cci_value  unemr_value  \
# 0  25/07/2017   75.0          13.08              1   99.34319         12.8
# 1  28/07/2017   75.0          20.02              1   99.34319         12.8
# 2  28/07/2017   75.0          20.02              1   99.34319         12.8
# 3  29/07/2017   75.0          13.08              2   99.34319         12.8
# 4  01/08/2017   75.0          13.08              3   99.37289         12.6
#
#    inflation_value
# 0         2.711626
# 1         2.711626
# 2         2.711626
# 3         2.711626
# 4         2.455909

# %%
# Convert the 'date' column in the 'train' DataFrame to datetime format
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_18020\3609160552.py:2: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %%
#inspecting df
df.dtypes
# Out:
# date               datetime64[ns]
# price                     float64
# freight_value             float64
# quantity_sold               int64
# cci_value                 float64
# unemr_value               float64
# inflation_value           float64
# dtype: object

# %%
#Rename variable
df = df.rename(columns = {'quantity_sold': 'y'})
df.head(0)
# Out:
# Empty DataFrame
# Columns: [date, price, freight_value, y, cci_value, unemr_value, inflation_value]
# Index: []

# %%
df.isnull().sum()
# Out:
# date               0
# price              0
# freight_value      0
# y                  0
# cci_value          0
# unemr_value        0
# inflation_value    0
# dtype: int64

# %% [markdown]
# #Silverkite Preparations

# %%
#Specifying Time Series names
metadata = MetadataParam(time_col = "date",
                         value_col = "y",
                         freq = "D",
                         train_end_date = pd.to_datetime("2018-08-18"))
metadata
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='D', time_col='date', train_end_date=Timestamp('2018-08-18 00:00:00'), value_col='y')

# %%
#growth terms possibilities
growth = dict(growth_term = ["linear", "quadratic", "sqrt"])
growth
# Out:
# {'growth_term': ['linear', 'quadratic', 'sqrt']}

# %%
#seasonalities
seasonality = dict(yearly_seasonality = "auto",
                   quarterly_seasonality = "auto",
                   monthly_seasonality = "auto",
                   weekly_seasonality = "auto",
                   daily_seasonality = "auto")
seasonality
# Out:
# {'yearly_seasonality': 'auto',
#  'quarterly_seasonality': 'auto',
#  'monthly_seasonality': 'auto',
#  'weekly_seasonality': 'auto',
#  'daily_seasonality': 'auto'}

# %%
#checking which countries are available and their holidays
get_available_holiday_lookup_countries(["Brazil"])
get_available_holidays_across_countries(countries = ["Brazil"],
                                        year_start = 2017,
                                        year_end = 2018)
# Out:
# ['All Souls Day',
#  'Ash Wednesday',
#  'Christmas Day',
#  'Corpus Christi Holiday',
#  'Easter',
#  'Good Friday',
#  'Independence Day',
#  'Labor Day',
#  "New Year's Day",
#  "Our Lady of Apparecida's Day",
#  'Pentecost',
#  'Proclamation of the Republic',
#  'Rio Carnival',
#  'Tiradentes',
#  'Trinity Sunday']

# %%
#Changepoints -> reflects the changes in the trend
changepoints = dict(changepoints_dict = dict(method = "auto"))

# %%
#Regressors
regressors = dict(regressor_cols = ["price", "freight_value", "cci_value",
                                    "unemr_value","inflation_value"])
regressors
# Out:
# {'regressor_cols': ['price',
#   'freight_value',
#   'cci_value',
#   'unemr_value',
#   'inflation_value']}

# %%
#Lagged Regressors
lagged_regressors = dict(lagged_regressor_dict = {"price": "auto",
                                                  "freight_value": "auto",
                                                  "cci_value": "auto",
                                                  "unemr_value": "auto",
                                                  "inflation_value": "auto",})

# %%
#autogression -> dependent on the forecasting horizon
autoregression = dict(autoreg_dict = "auto")

# %%
#Fitting algorithms
custom = dict(fit_algorithm_dict = [dict(fit_algorithm = "linear"),
                                    dict(fit_algorithm = "ridge"),
                                    dict(fit_algorithm = "rf"),
                                    dict(fit_algorithm = "gradient_boosting")])
custom
# Out:
# {'fit_algorithm_dict': [{'fit_algorithm': 'linear'},
#   {'fit_algorithm': 'ridge'},
#   {'fit_algorithm': 'rf'},
#   {'fit_algorithm': 'gradient_boosting'}]}

# %% [markdown]
# #Silverkite Model

# %%
#Build the model
model_components = ModelComponentsParam(growth = growth,
                                        seasonality = seasonality,
                                        changepoints = changepoints,
                                        regressors = regressors,
                                        lagged_regressors = lagged_regressors,
                                        autoregression = autoregression,
                                        custom = custom)

# %%
#Cross-validation
evaluation_period = EvaluationPeriodParam(cv_min_train_periods= df.shape[0] - 180 -31,
                                          cv_expanding_window = True,
                                          cv_max_splits = 50,
                                          cv_periods_between_splits = 16)

# %%
#Evaluation metric 
evaluation_metric = EvaluationMetricParam(
    cv_selection_metric = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Configuration
config = ForecastConfig(model_template = ModelTemplateEnum.SILVERKITE.name,
                        forecast_horizon = 31,
                        metadata_param = metadata,
                        model_components_param = model_components,
                        evaluation_period_param=evaluation_period,
                        evaluation_metric_param = evaluation_metric)

# %%
#Forecasting
forecaster = Forecaster()
result = forecaster.run_forecast_config(df = df,
                                        config = config)
# Out:
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\time_properties.py:351: UserWarning:
#
# Duplicate timestamps have been removed.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\time_properties.py:127: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\time_properties.py:351: UserWarning:
#
# Duplicate timestamps have been removed.
# Fitting 8 folds for each of 12 candidates, totalling 96 fits
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['cos4_tow_weekly']
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 12.90% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 4 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 61.11% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 132 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['cos4_tow_weekly']
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 16.13% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 5 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 57.33% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 133 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['cos4_tow_weekly']
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 1 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 55.24% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 137 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# ...
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 49.70% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 163 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning:
#
# One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 53.48% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 53.48% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 56.15% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 56.15% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 192 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:153: UserWarning:
#
# 27 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\common\evaluation.py:483: UserWarning:
#
# y_true is constant. Correlation is not defined.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 56.15% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\transform\null_transformer.py:177: RuntimeWarning:
#
# Input data has many null values. Missing 56.15% of one input.
#
# c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\framework\input\univariate_time_series.py:357: UserWarning:
#
# Provided periods '31' is more than allowed ('0') due to the length of regressor columns. Using '0'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ratho\Desktop\data anlysis\pull_github\price_optimization\LinkedIn Silverkite - Parameter Tuning.ipynb Cell 22 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ratho/Desktop/data%20anlysis/pull_github/price_optimization/LinkedIn%20Silverkite%20-%20Parameter%20Tuning.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> #Forecasting
#       <a href='vscode-notebook-cell:/c%3A/Users/ratho/Desktop/data%20anlysis/pull_github/price_optimization/LinkedIn%20Silverkite%20-%20Parameter%20Tuning.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> forecaster = Forecaster()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ratho/Desktop/data%20anlysis/pull_github/price_optimization/LinkedIn%20Silverkite%20-%20Parameter%20Tuning.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> result = forecaster.run_forecast_config(df = df,
#       <a href='vscode-notebook-cell:/c%3A/Users/ratho/Desktop/data%20anlysis/pull_github/price_optimization/LinkedIn%20Silverkite%20-%20Parameter%20Tuning.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a>                                         config = config)
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\framework\templates\forecaster.py:378, in Forecaster.run_forecast_config(self, df, config)
#     353 """Creates a forecast from input data and config.
#     354 The result is also stored as ``self.forecast_result``.
#     355
#    (...)
#     373     according to the ``df`` and ``config`` configuration parameters.
#     374 """
#     375 pipeline_parameters = self.apply_forecast_config(
#     376     df=df,
#     377     config=config)
# --> 378 self.forecast_result = forecast_pipeline(**pipeline_parameters)
#     379 return self.forecast_result
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\framework\pipeline\pipeline.py:209, in validate_pipeline_input.<locals>.pipeline_wrapper(df, time_col, value_col, date_format, tz, freq, train_end_date, anomaly_info, pipeline, regressor_cols, lagged_regressor_cols, estimator, hyperparameter_grid, hyperparameter_budget, n_jobs, verbose, forecast_horizon, coverage, test_horizon, periods_between_train_test, agg_periods, agg_func, score_func, score_func_greater_is_better, cv_report_metrics, null_model_params, relative_error_tolerance, cv_horizon, cv_min_train_periods, cv_expanding_window, cv_use_most_recent_splits, cv_periods_between_splits, cv_periods_between_train_test, cv_max_splits)
#     206 log_message(f"test_horizon: {test_horizon}", LoggingLevelEnum.INFO)
#     207 log_message(f"cv_horizon: {cv_horizon}", LoggingLevelEnum.INFO)
# --> 209 return pipeline_function(
#     210     df,
#     211     time_col=time_col,
#     212     value_col=value_col,
#     213     date_format=date_format,
#     214     tz=tz,
#     215     freq=freq,
#     216     train_end_date=train_end_date,
#     217     anomaly_info=anomaly_info,
#     218     pipeline=pipeline,
#     219     regressor_cols=regressor_cols,
#     220     lagged_regressor_cols=lagged_regressor_cols,
#     221     estimator=estimator,
#     222     hyperparameter_grid=hyperparameter_grid,
#     223     hyperparameter_budget=hyperparameter_budget,
#     224     n_jobs=n_jobs,
#     225     verbose=verbose,
#     226     forecast_horizon=forecast_horizon,
#     227     coverage=coverage,
#     228     test_horizon=test_horizon,
#     229     periods_between_train_test=periods_between_train_test,
#     230     agg_periods=agg_periods,
#     231     agg_func=agg_func,
#     232     score_func=score_func,
#     233     score_func_greater_is_better=score_func_greater_is_better,
#     234     cv_report_metrics=cv_report_metrics,
#     235     null_model_params=null_model_params,
#     236     relative_error_tolerance=relative_error_tolerance,
#     237     cv_horizon=cv_horizon,
#     238     cv_min_train_periods=cv_min_train_periods,
#     239     cv_expanding_window=cv_expanding_window,
#     240     cv_use_most_recent_splits=cv_use_most_recent_splits,
#     241     cv_periods_between_splits=cv_periods_between_splits,
#     242     cv_periods_between_train_test=cv_periods_between_train_test,
#     243     cv_max_splits=cv_max_splits
#     244 )
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\framework\pipeline\pipeline.py:748, in forecast_pipeline(df, time_col, value_col, date_format, tz, freq, train_end_date, anomaly_info, pipeline, regressor_cols, lagged_regressor_cols, estimator, hyperparameter_grid, hyperparameter_budget, n_jobs, verbose, forecast_horizon, coverage, test_horizon, periods_between_train_test, agg_periods, agg_func, score_func, score_func_greater_is_better, cv_report_metrics, null_model_params, relative_error_tolerance, cv_horizon, cv_min_train_periods, cv_expanding_window, cv_use_most_recent_splits, cv_periods_between_splits, cv_periods_between_train_test, cv_max_splits)
#     743 # Uses pd.date_range because pd.Timedelta does not work for complicated frequencies e.g. "W-MON"
#     744 forecast_test_start_date = pd.date_range(
#     745     start=forecast_train_end_date,
#     746     periods=periods_between_train_test + 2,  # Adds 2 as start parameter is inclusive
#     747     freq=ts.freq)[-1]
# --> 748 forecast = get_forecast(
#     749     df=future_df,
#     750     trained_model=best_pipeline,
#     751     train_end_date=forecast_train_end_date,
#     752     test_start_date=forecast_test_start_date,
#     753     forecast_horizon=forecast_horizon,
#     754     xlabel=time_col,
#     755     ylabel=value_col,
#     756     relative_error_tolerance=relative_error_tolerance)
#     758 result = ForecastResult(
#     759     timeseries=ts,
#     760     grid_search=grid_search,
#    (...)
#     763     forecast=forecast
#     764 )
#     765 return result
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\framework\pipeline\utils.py:769, in get_forecast(df, trained_model, train_end_date, test_start_date, forecast_horizon, xlabel, ylabel, relative_error_tolerance)
#     726 def get_forecast(
#     727         df,
#     728         trained_model: Pipeline,
#    (...)
#     733         ylabel=cst.VALUE_COL,
#     734         relative_error_tolerance=None) -> UnivariateForecast:
#     735     """Runs model predictions on ``df`` and creates a
#     736     `~greykite.framework.output.univariate_forecast.UnivariateForecast` object.
#     737
#    (...)
#     767         Forecasts represented as a ``UnivariateForecast`` object.
#     768     """
# --> 769     predicted_df = trained_model.predict(df)
#     770     # This is more robust than using trained_model.named_steps["estimator"] e.g.
#     771     # if the user calls forecast_pipeline with a custom pipeline, where the last
#     772     # step isn't named "estimator".
#     773     trained_estimator = trained_model.steps[-1][-1]
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\sklearn\pipeline.py:508, in Pipeline.predict(self, X, **predict_params)
#     506 for _, name, transform in self._iter(with_final=False):
#     507     Xt = transform.transform(Xt)
# --> 508 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\sklearn\estimator\base_silverkite_estimator.py:358, in BaseSilverkiteEstimator.predict(self, X, y)
#     355 if self.pred_cols is None:
#     356     raise NotFittedError("Subclass must call `finish_fit` inside the `fit` method.")
# --> 358 pred_res = self.silverkite.predict(
#     359     fut_df=X,
#     360     trained_model=self.model_dict,
#     361     past_df=self.past_df,
#     362     new_external_regressor_df=None)  # regressors are included in X
#     363 pred_df = pred_res["fut_df"]
#     364 x_mat = pred_res["x_mat"]
#
# File c:\Users\ratho\anaconda3\envs\kite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_silverkite.py:2114, in SilverkiteForecast.predict(self, fut_df, trained_model, freq, past_df, new_external_regressor_df, include_err, force_no_sim, simulation_num, fast_simulation, na_fill_func)
#    2111     freq = trained_model["freq"]
#    2113 if fut_df.shape[0] <= 0:
# -> 2114     raise ValueError("``fut_df`` must be a dataframe of non-zero size.")
#    2116 if time_col not in fut_df.columns:
#    2117     raise ValueError(
#    2118         f"``fut_df`` must include {time_col} as time column, "
#    2119         "which is what ``trained_model`` considers to be the time column.")
#
# ValueError: ``fut_df`` must be a dataframe of non-zero size.

# %%
#visualization
fig = result.backtest.plot()
iplot(fig)

# %% [markdown]
# #Parameter Tuning results

# %%
#CV results
cv_results = summarize_grid_search_results(
    grid_search = result.grid_search,
    decimals = 1,
    score_func = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Set the CV results index
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop = True, inplace = True)
cv_results
# Out:
#                                                     rank_test_CORR  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               2
# [('estimator__growth_term', 'quadratic'), ('est...               1
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               5
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               6
# [('estimator__growth_term', 'linear'), ('estima...              10
# [('estimator__growth_term', 'quadratic'), ('est...              12
# [('estimator__growth_term', 'sqrt'), ('estimato...              11
# [('estimator__growth_term', 'linear'), ('estima...               8
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               7
#
#                                                     rank_test_R2  \
# params
# [('estimator__growth_term', 'linear'), ('estima...             2
# [('estimator__growth_term', 'quadratic'), ('est...             1
# [('estimator__growth_term', 'sqrt'), ('estimato...             3
# [('estimator__growth_term', 'linear'), ('estima...             6
# [('estimator__growth_term', 'quadratic'), ('est...             4
# [('estimator__growth_term', 'sqrt'), ('estimato...             5
# [('estimator__growth_term', 'linear'), ('estima...            10
# [('estimator__growth_term', 'quadratic'), ('est...            11
# [('estimator__growth_term', 'sqrt'), ('estimato...            12
# [('estimator__growth_term', 'linear'), ('estima...             7
# [('estimator__growth_term', 'quadratic'), ('est...             9
# [('estimator__growth_term', 'sqrt'), ('estimato...             8
#
#                                                     rank_test_MSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...              2
# [('estimator__growth_term', 'quadratic'), ('est...              1
# [('estimator__growth_term', 'sqrt'), ('estimato...              3
# [('estimator__growth_term', 'linear'), ('estima...              6
# [('estimator__growth_term', 'quadratic'), ('est...              4
# [('estimator__growth_term', 'sqrt'), ('estimato...              5
# [('estimator__growth_term', 'linear'), ('estima...             10
# [('estimator__growth_term', 'quadratic'), ('est...             11
# [('estimator__growth_term', 'sqrt'), ('estimato...             12
# [('estimator__growth_term', 'linear'), ('estima...              7
# [('estimator__growth_term', 'quadratic'), ('est...              9
# [('estimator__growth_term', 'sqrt'), ('estimato...              8
#
#                                                     rank_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               2
# [('estimator__growth_term', 'quadratic'), ('est...               1
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               6
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               5
# [('estimator__growth_term', 'linear'), ('estima...              10
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              12
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     rank_test_MAE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...              1
# [('estimator__growth_term', 'quadratic'), ('est...              2
# [('estimator__growth_term', 'sqrt'), ('estimato...              3
# [('estimator__growth_term', 'linear'), ('estima...              6
# [('estimator__growth_term', 'quadratic'), ('est...              4
# [('estimator__growth_term', 'sqrt'), ('estimato...              5
# [('estimator__growth_term', 'linear'), ('estima...             10
# [('estimator__growth_term', 'quadratic'), ('est...             12
# [('estimator__growth_term', 'sqrt'), ('estimato...             11
# [('estimator__growth_term', 'linear'), ('estima...              7
# [('estimator__growth_term', 'quadratic'), ('est...              9
# [('estimator__growth_term', 'sqrt'), ('estimato...              8
#
#                                                     rank_test_MedAE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                3
# [('estimator__growth_term', 'quadratic'), ('est...                1
# [('estimator__growth_term', 'sqrt'), ('estimato...                2
# [('estimator__growth_term', 'linear'), ('estima...                6
# [('estimator__growth_term', 'quadratic'), ('est...                4
# [('estimator__growth_term', 'sqrt'), ('estimato...                5
# [('estimator__growth_term', 'linear'), ('estima...               11
# [('estimator__growth_term', 'quadratic'), ('est...               10
# [('estimator__growth_term', 'sqrt'), ('estimato...               12
# [('estimator__growth_term', 'linear'), ('estima...                7
# [('estimator__growth_term', 'quadratic'), ('est...                9
# [('estimator__growth_term', 'sqrt'), ('estimato...                8
#
#                                                     rank_test_MAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               1
# [('estimator__growth_term', 'quadratic'), ('est...               2
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               5
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               6
# [('estimator__growth_term', 'linear'), ('estima...              10
# [('estimator__growth_term', 'quadratic'), ('est...              12
# [('estimator__growth_term', 'sqrt'), ('estimato...              11
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     rank_test_MedAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                 3
# [('estimator__growth_term', 'quadratic'), ('est...                 1
# [('estimator__growth_term', 'sqrt'), ('estimato...                 2
# [('estimator__growth_term', 'linear'), ('estima...                 6
# [('estimator__growth_term', 'quadratic'), ('est...                 4
# [('estimator__growth_term', 'sqrt'), ('estimato...                 5
# [('estimator__growth_term', 'linear'), ('estima...                10
# [('estimator__growth_term', 'quadratic'), ('est...                11
# [('estimator__growth_term', 'sqrt'), ('estimato...                12
# [('estimator__growth_term', 'linear'), ('estima...                 7
# [('estimator__growth_term', 'quadratic'), ('est...                 9
# [('estimator__growth_term', 'sqrt'), ('estimato...                 8
#
#                                                     rank_test_sMAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                1
# [('estimator__growth_term', 'quadratic'), ('est...                2
# [('estimator__growth_term', 'sqrt'), ('estimato...                3
# [('estimator__growth_term', 'linear'), ('estima...                6
# [('estimator__growth_term', 'quadratic'), ('est...                4
# [('estimator__growth_term', 'sqrt'), ('estimato...                5
# [('estimator__growth_term', 'linear'), ('estima...               10
# [('estimator__growth_term', 'quadratic'), ('est...               12
# [('estimator__growth_term', 'sqrt'), ('estimato...               11
# [('estimator__growth_term', 'linear'), ('estima...                7
# [('estimator__growth_term', 'quadratic'), ('est...                9
# [('estimator__growth_term', 'sqrt'), ('estimato...                8
#
#                                                     rank_test_Q80  ...  \
# params                                                             ...
# [('estimator__growth_term', 'linear'), ('estima...              8  ...
# [('estimator__growth_term', 'quadratic'), ('est...              6  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              7  ...
# [('estimator__growth_term', 'linear'), ('estima...             12  ...
# [('estimator__growth_term', 'quadratic'), ('est...             10  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...             11  ...
# [('estimator__growth_term', 'linear'), ('estima...              5  ...
# [('estimator__growth_term', 'quadratic'), ('est...              9  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              4  ...
# [('estimator__growth_term', 'linear'), ('estima...              1  ...
# [('estimator__growth_term', 'quadratic'), ('est...              3  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              2  ...
#
#                                                     std_test_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
# [('estimator__growth_term', 'linear'), ('estima...                          0.0
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.0
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
#
#                                                     split0_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.5
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split1_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.5
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split2_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split3_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split4_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split5_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split6_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split7_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     std_train_OutsideTolerance5p
# params
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
#
# [12 rows x 436 columns]

# %%
#Looking at the best results
cv_results[["rank_test_RMSE", "mean_test_RMSE",
            "param_estimator__fit_algorithm_dict",
            "param_estimator__growth_term"]]
# Out:
#                                                     rank_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               2
# [('estimator__growth_term', 'quadratic'), ('est...               1
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               6
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               5
# [('estimator__growth_term', 'linear'), ('estima...              10
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              12
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     mean_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...            47.8
# [('estimator__growth_term', 'quadratic'), ('est...            47.8
# [('estimator__growth_term', 'sqrt'), ('estimato...            47.9
# [('estimator__growth_term', 'linear'), ('estima...            48.9
# [('estimator__growth_term', 'quadratic'), ('est...            48.5
# [('estimator__growth_term', 'sqrt'), ('estimato...            48.9
# [('estimator__growth_term', 'linear'), ('estima...            63.6
# [('estimator__growth_term', 'quadratic'), ('est...            64.8
# [('estimator__growth_term', 'sqrt'), ('estimato...            65.2
# [('estimator__growth_term', 'linear'), ('estima...            56.5
# [('estimator__growth_term', 'quadratic'), ('est...            59.5
# [('estimator__growth_term', 'sqrt'), ('estimato...            56.5
#
#                                                        param_estimator__fit_algorithm_dict  \
# params
# [('estimator__growth_term', 'linear'), ('estima...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'quadratic'), ('est...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'sqrt'), ('estimato...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'linear'), ('estima...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'quadratic'), ('est...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'sqrt'), ('estimato...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'linear'), ('estima...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'quadratic'), ('est...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'sqrt'), ('estimato...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'linear'), ('estima...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__growth_term', 'quadratic'), ('est...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__growth_term', 'sqrt'), ('estimato...  {'fit_algorithm': 'gradient_boosting'}
#
#                                                    param_estimator__growth_term
# params
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt

# %%
best_params = cv_results[cv_results.rank_test_RMSE == 1][["mean_test_RMSE",
                                            "param_estimator__fit_algorithm_dict",
                                            "param_estimator__growth_term"]].transpose()

# %%
best_params.to_csv("C:/Users/ratho/Desktop/new/learn/time_series_forecasting/Forecasting Product/best_params_silverkite_lr.csv")
